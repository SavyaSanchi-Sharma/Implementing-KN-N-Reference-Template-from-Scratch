# %%
import pandas as pd 
import numpy as np 
import KNN

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
X=train[['x1','x2']].values
y=train['Class'].values

# %%
X.shape
# Out:
# (1260, 2)

# %%
knn=KNN.KNN(k=9)
knn.fit(X,y)
knn.plot_decision_boundary(X, y)

# %%
x=test[['x1','x2']].values
y_true=test['Class'].values
x
# Out:
# array([[-0.475795,  0.703921],
#        [-0.490811,  0.860318],
#        [ 0.426465,  0.997589],
#        ...,
#        [ 4.478385, -1.140949],
#        [-3.563939, -4.183029],
#        [-4.781256, -0.034948]])

# %%
final_pred=pd.DataFrame(x,columns=['x1','x2'])
final_pred['y_cap']=knn.predict(x)
final_pred
# Out:
#            x1        x2  y_cap
# 0   -0.475795  0.703921      1
# 1   -0.490811  0.860318      1
# 2    0.426465  0.997589      1
# 3   -0.465864  0.067546      1
# 4   -0.546006 -0.868762      1
# ..        ...       ...    ...
# 535  4.909242  0.227690      3
# 536  5.249636 -1.973015      3
# 537  4.478385 -1.140949      3
# 538 -3.563939 -4.183029      3
# 539 -4.781256 -0.034948      3
#
# [540 rows x 3 columns]

# %%
f=final_pred[['x1','x2']].values
y_hat=final_pred['y_cap'].values

# %%
import accuracy
acc=accuracy.accuracy(y_true,y_hat)

# %%
acc.confusion_matrix()
# Out:
# array([[  0,   0,   0,   0],
#        [  0,  96,   0,   0],
#        [  0,   0, 128,   0],
#        [  0,   0,   0, 316]])

# %%
acc.accu_percent()
# Out:
# 100.0

# %%
acc.precision()
# Out:
# Precision for class 1 is
# 1.0
# Precision for class 2 is
# 1.0
# Precision for class 3 is
# 1.0
# [1.0, 1.0, 1.0]

# %%
acc.recall()
# Out:
# Recall for class1 is
# 1.0
# Recall for class2 is
# 1.0
# Recall for class3 is
# 1.0
# [1.0, 1.0, 1.0]

# %%
acc.f_score()
# Out:
# Precision for class 1 is
# 1.0
# Precision for class 2 is
# 1.0
# Precision for class 3 is
# 1.0
# Recall for class1 is
# 1.0
# Recall for class2 is
# 1.0
# Recall for class3 is
# 1.0
# F-score for class 1 is 1.0
# F-score for class 2 is 1.0
# F-score for class 3 is 1.0
# [1.0, 1.0, 1.0]
